# %% [markdown]
# # Importing the Libraries

# %%
import utils as ui

# %% [markdown]
# # Reading the CSV Files

# %%
df_PPCA = df = ui.load_csv('Datasets\With Imputation\PPCA Imputation\Ghaziabad_PPCA.csv')
df_ET=ui.load_csv('Datasets\With Imputation\ET_Regressor Imputation\Ghaziabad_ET.csv')
df_raw= ui.load_csv('.\Datasets\Without Imputation\Final_Dataset_Ghaziabad.csv')

# %% [markdown]
# # Data Visualization
#
# ## Correlation Matrix

# %%
ui.correlation(df)

# %% [markdown]
# ## Monthly Distribution of Pollutant Levels For All

# %%
ui.plot_monthly_levels(df,['PM2.5','PM10','NO2','NH3','SO2','CO','Ozone'])

# %% [markdown]
# ## Monthly Distribution Of The Values For Each Variable

# %%
ui.monthly_distribution([df_raw,df_PPCA], ['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO','Ozone','Temp','RH','WS','WD'], labels=['Raw', 'PPCA Imputed'])

# %% [markdown]
# ## Frequency Distribution Graphs Of The Values For Each Variable

# %%
ui.freq_distribution([df_raw,df_PPCA,df_ET], ['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO','Ozone','Temp','RH','WS','WD'], labels=['Raw', 'PPCA Imputed','ET_Regressor'])

# %% [markdown]
# ## Day Wise Distribution Of The Variables

# %%
ui.day_distribution([df_PPCA,df_ET,df_raw], ['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO','Ozone','Temp','RH','WS','WD'], labels=['PPCA Imputed','ET_Regressor','Raw'],date='2018-01-01')

# %% [markdown]
# ## Seasonality Graph of Any Variable

# %%
ui.seasonality_plot(df,'2017-12-15', '2018-1-1','PM2.5')

# %% [markdown]
# ## Hourly Distribution Of The Variables

# %%
ui.hour_wise_distribution(df,variables = ['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO','Ozone','Temp','RH','WS','WD'])

# %% [markdown]
# ## Monthly Distribution Of The Variables

# %%
ui.month_wise_distribution(df,variables = ['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO','Ozone','Temp','RH','WS','WD'])

# %% [markdown]
# ## Week Wise Distribution Of The Variables

# %%
ui.week_wise_distribution(df,variables = ['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO','Ozone','Temp','RH','WS','WD'],n_col=1)

# %% [markdown]
# ## Day Of The Week Wise Distribution Of The Variables

# %%
ui.day_of_week_wise_distribution(df,variables = ['PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO','Ozone','Temp','RH','WS','WD'])
